# %%
import pandas as pd

# %%
PATH_TO_JSON = 'trial_task.json'
raw_df = pd.read_json(PATH_TO_JSON)

# %%
raw_df.head()
# Out:
#    order_id       warehouse_name  highway_cost  \
# 0     11973               Мордор           -70
# 1     62239  хутор близ Диканьки           -15
# 2     85794           отель Лето           -50
# 3     33684               Мордор           -30
# 4     25824           отель Лето           -75
#
#                                             products
# 0  [{'product': 'ломтик июльского неба', 'price':...
# 1  [{'product': 'билет в Израиль', 'price': 1000,...
# 2  [{'product': 'зеленая пластинка', 'price': 10,...
# 3  [{'product': 'билет в Израиль', 'price': 1000,...
# 4  [{'product': 'автограф Стаса Барецкого', 'pric...

# %%
print('колличество строк без товаров:',raw_df[raw_df['products'].apply(lambda x: len(x) == 0)].shape)
print('незаполненные строки:',raw_df[raw_df.isna().any(axis=1)].shape)
# Out:
# колличество строк без товаров: (0, 4)
# незаполненные строки: (0, 4)

# %%
cols_names= ['order_id','warehouse_name','highway_cost','product','price','quantity']

exploded_df = raw_df.explode('products')
full_df = pd.DataFrame(exploded_df['products'].tolist(), index=exploded_df.index)
full_df['order_id'] = exploded_df['order_id']
full_df['warehouse_name'] = exploded_df['warehouse_name']
full_df['highway_cost'] = exploded_df['highway_cost']
full_df = full_df.reindex(columns=cols_names).reset_index(drop=True)

full_df.head()
# Out:
#    order_id       warehouse_name  highway_cost                product  price  \
# 0     11973               Мордор           -70  ломтик июльского неба    450
# 1     11973               Мордор           -70        билет в Израиль   1000
# 2     11973               Мордор           -70       статуэтка Ленина    200
# 3     62239  хутор близ Диканьки           -15        билет в Израиль   1000
# 4     85794           отель Лето           -50      зеленая пластинка     10
#
#    quantity
# 0         1
# 1         3
# 2         3
# 3         1
# 4         2

# %% [markdown]
# ## 1. Найти тариф стоимости доставки для каждого склада

# %% [markdown]
# ### Вычисления

# %%
def culc_tarif(row):
    total_quantity = 0
    for prodact in row['products']:
        total_quantity += prodact['quantity']
    tarif = -int(row['highway_cost']/total_quantity)
    return tarif
        

warehouse_df = raw_df.groupby('warehouse_name').head(1).copy()
warehouse_df['tarif'] = warehouse_df.apply(culc_tarif, axis=1)
warehouse_tarif_df = warehouse_df[['warehouse_name','tarif']].reset_index(drop=True)

# %% [markdown]
# ### Итог

# %%
warehouse_tarif_df
# Out:
#         warehouse_name  tarif
# 0               Мордор     10
# 1  хутор близ Диканьки     15
# 2           отель Лето     25
# 3     остров невезения      5
# 4           гиперборея     20

# %% [markdown]
# ## 2. Найти суммарное количество , суммарный доход , суммарный расход и суммарную прибыль для каждого товара (представить как таблицу со столбцами 'product', 'quantity', 'income', 'expenses', 'profit')

# %% [markdown]
# ### Вычисления

# %%
product_temp_df = full_df.copy()
product_temp_df['income'] = product_temp_df['price'] * product_temp_df['quantity']
product_df = product_temp_df.groupby('product', as_index=False).agg({
    'quantity': 'sum',
    'income': 'sum',
    'highway_cost': lambda x: -x.sum()
}).rename(columns={'highway_cost': 'expenses'})
product_df['profit'] = product_df['income'] - product_df['expenses']

# %% [markdown]
# ### Итог

# %%
product_df
# Out:
#                     product  quantity  income  expenses  profit
# 0  автограф Стаса Барецкого        48   28800      2090   26710
# 1           билет в Израиль        58   58000      2305   55695
# 2         зеленая пластинка        61     610      2260   -1650
# 3     ломтик июльского неба        42   18900      1210   17690
# 4                   плюмбус        65   16250      2255   13995
# 5    подписка на suppi-блог        33    4950      1415    3535
# 6          статуэтка Ленина        68   13600      2235   11365

# %% [markdown]
# ## Составить табличку со столбцами 'order_id' (id заказа) и 'order_profit' (прибыль полученная с заказа). А также вывести среднюю прибыль заказов

# %% [markdown]
# ### Вычисления

# %%
temp_product_df = full_df.copy()
temp_product_df['posision_profit'] = temp_product_df['highway_cost'] + temp_product_df['price'] * temp_product_df[
    'quantity']

order_profit_df = temp_product_df[['order_id', 'posision_profit']].\
    groupby('order_id').sum().\
    rename(columns={"posision_profit": "order_profit"})
mean_order_profit = order_profit_df['order_profit'].mean()
del temp_product_df

# %% [markdown]
# ### Итог

# %%
order_profit_df
# Out:
#           order_profit
# order_id
# 124                705
# 1391               490
# 2091              1200
# 2108               190
# 2558               205
# ...                ...
# 98100             1580
# 98423             1170
# 99220              925
# 99246             1755
# 99324             1580
#
# [100 rows x 1 columns]

# %%
print('Средняя прибыль заказов:',mean_order_profit)
# Out:
# Средняя прибыль заказов: 1273.4

# %% [markdown]
# ## 4. Составить табличку типа 'warehouse_name' , 'product','quantity', 'profit', 'percent_profit_product_of_warehouse' (процент прибыли продукта заказанного из определенного склада к прибыли этого склада)

# %% [markdown]
# ### Вычисления

# %%
temp_warehouse_df = full_df.copy()
temp_warehouse_df['posision_profit'] = temp_warehouse_df['highway_cost'] + temp_warehouse_df['price'] * \
                                       temp_warehouse_df['quantity']

grouped_df = temp_warehouse_df.groupby(['warehouse_name', 'product'], as_index=False).agg({
    'quantity': 'sum',
    'posision_profit': 'sum'
})
del temp_warehouse_df
warehouse_profit_df = grouped_df.groupby('warehouse_name')['posision_profit'].sum().reset_index()
warehouse_profit_df.rename(columns={'posision_profit': 'warehouse_profit'}, inplace=True)

merged_df = pd.merge(grouped_df, warehouse_profit_df, on='warehouse_name')
merged_df['percent_profit_product_of_warehouse'] = (merged_df['posision_profit'] / merged_df['warehouse_profit']) * 100
merged_df.rename(columns={'posision_profit': 'profit'}, inplace=True)
warehouse_df = merged_df[['warehouse_name', 'product', 'quantity', 'profit', 'percent_profit_product_of_warehouse']]
del warehouse_profit_df
del merged_df

# %% [markdown]
# ### Итог

# %%
warehouse_df
# Out:
#          warehouse_name                   product  quantity  profit  \
# 0                Мордор  автограф Стаса Барецкого         4    2290
# 1                Мордор           билет в Израиль         9    8860
# 2                Мордор         зеленая пластинка        11     -80
# 3                Мордор     ломтик июльского неба         3    1260
# 4                Мордор                   плюмбус         6    1360
# 5                Мордор    подписка на suppi-блог         8     980
# 6                Мордор          статуэтка Ленина        10    1810
# 7            гиперборея  автограф Стаса Барецкого        12    6560
# 8            гиперборея           билет в Израиль        21   20020
# 9            гиперборея         зеленая пластинка        10    -480
# 10           гиперборея     ломтик июльского неба        13    5390
# 11           гиперборея                   плюмбус         9    1810
# 12           гиперборея    подписка на suppi-блог        12    1180
# 13           гиперборея          статуэтка Ленина         9    1280
# 14     остров невезения  автограф Стаса Барецкого         2    1180
# 15     остров невезения           билет в Израиль         3    2975
# 16     остров невезения         зеленая пластинка         9     -20
# 17     остров невезения     ломтик июльского неба        10    4395
# 18     остров невезения                   плюмбус        14    3330
# 19     остров невезения          статуэтка Ленина        18    3410
# 20           отель Лето  автограф Стаса Барецкого         8    4275
# 21           отель Лето           билет в Израиль        15   14200
# 22           отель Лето         зеленая пластинка        10    -500
# 23           отель Лето     ломтик июльского неба         9    3675
# 24           отель Лето                   плюмбус         9    1825
# 25           отель Лето    подписка на suppi-блог         3     250
# 26           отель Лето          статуэтка Ленина        10    1475
# 27  хутор близ Диканьки  автограф Стаса Барецкого        22   12405
# 28  хутор близ Диканьки           билет в Израиль        10    9640
# 29  хутор близ Диканьки         зеленая пластинка        21    -570
# 30  хутор близ Диканьки     ломтик июльского неба         7    2970
# 31  хутор близ Диканьки                   плюмбус        27    5670
# 32  хутор близ Диканьки    подписка на suppi-блог        10    1125
# 33  хутор близ Диканьки          статуэтка Ленина        21    3390
#
#     percent_profit_product_of_warehouse
# 0                             13.895631
# 1                             53.762136
# 2                             -0.485437
# 3                              7.645631
# 4                              8.252427
# 5                              5.946602
# 6                             10.983010
# 7                             18.344519
# 8                             55.984340
# 9                             -1.342282
# 10                            15.072707
# 11                             5.061521
# 12                             3.299776
# 13                             3.579418
# 14                             7.727570
# 15                            19.482646
# 16                            -0.130976
# 17                            28.781925
# 18                            21.807466
# 19                            22.331369
# 20                            16.964286
# 21                            56.349206
# 22                            -1.984127
# 23                            14.583333
# 24                             7.242063
# 25                             0.992063
# 26                             5.853175
# 27                            35.821542
# 28                            27.837135
# 29                            -1.645972
# 30                             8.576379
# 31                            16.373087
# 32                             3.248628
# 33                             9.789200

# %% [markdown]
# ## 5. Взять предыдущую табличку и отсортировать 'percent_profit_product_of_warehouse' по убыванию, после посчитать накопленный процент. Накопленный процент - это новый столбец в этой табличке, который должен называться 'accumulated_percent_profit_product_of_warehouse'. По своей сути это постоянно растущая сумма отсортированного по убыванию столбца 'percent_profit_product_of_warehouse'.

# %% [markdown]
# ### Вычисления

# %%
grouped_by_warehouse_df = warehouse_df.groupby('warehouse_name',as_index=False).apply(lambda x: x.sort_values('percent_profit_product_of_warehouse', ascending=False))
grouped_by_warehouse_df['accumulated_percent_profit_product_of_warehouse'] = grouped_by_warehouse_df.groupby('warehouse_name', as_index=False)['percent_profit_product_of_warehouse'].cumsum()
grouped_by_warehouse_df = grouped_by_warehouse_df.reset_index(drop=True)

# %% [markdown]
# ### Итог

# %%
# С группировкой по складам
grouped_by_warehouse_df
# Out:
#          warehouse_name                   product  quantity  profit  \
# 0                Мордор           билет в Израиль         9    8860
# 1                Мордор  автограф Стаса Барецкого         4    2290
# 2                Мордор          статуэтка Ленина        10    1810
# 3                Мордор                   плюмбус         6    1360
# 4                Мордор     ломтик июльского неба         3    1260
# 5                Мордор    подписка на suppi-блог         8     980
# 6                Мордор         зеленая пластинка        11     -80
# 7            гиперборея           билет в Израиль        21   20020
# 8            гиперборея  автограф Стаса Барецкого        12    6560
# 9            гиперборея     ломтик июльского неба        13    5390
# 10           гиперборея                   плюмбус         9    1810
# 11           гиперборея          статуэтка Ленина         9    1280
# 12           гиперборея    подписка на suppi-блог        12    1180
# 13           гиперборея         зеленая пластинка        10    -480
# 14     остров невезения     ломтик июльского неба        10    4395
# 15     остров невезения          статуэтка Ленина        18    3410
# 16     остров невезения                   плюмбус        14    3330
# 17     остров невезения           билет в Израиль         3    2975
# 18     остров невезения  автограф Стаса Барецкого         2    1180
# 19     остров невезения         зеленая пластинка         9     -20
# 20           отель Лето           билет в Израиль        15   14200
# 21           отель Лето  автограф Стаса Барецкого         8    4275
# 22           отель Лето     ломтик июльского неба         9    3675
# 23           отель Лето                   плюмбус         9    1825
# 24           отель Лето          статуэтка Ленина        10    1475
# 25           отель Лето    подписка на suppi-блог         3     250
# 26           отель Лето         зеленая пластинка        10    -500
# 27  хутор близ Диканьки  автограф Стаса Барецкого        22   12405
# 28  хутор близ Диканьки           билет в Израиль        10    9640
# 29  хутор близ Диканьки                   плюмбус        27    5670
# 30  хутор близ Диканьки          статуэтка Ленина        21    3390
# 31  хутор близ Диканьки     ломтик июльского неба         7    2970
# 32  хутор близ Диканьки    подписка на suppi-блог        10    1125
# 33  хутор близ Диканьки         зеленая пластинка        21    -570
#
#     percent_profit_product_of_warehouse  \
# 0                             53.762136
# 1                             13.895631
# 2                             10.983010
# 3                              8.252427
# 4                              7.645631
# 5                              5.946602
# 6                             -0.485437
# 7                             55.984340
# 8                             18.344519
# 9                             15.072707
# 10                             5.061521
# 11                             3.579418
# 12                             3.299776
# 13                            -1.342282
# 14                            28.781925
# 15                            22.331369
# 16                            21.807466
# 17                            19.482646
# 18                             7.727570
# 19                            -0.130976
# 20                            56.349206
# 21                            16.964286
# 22                            14.583333
# 23                             7.242063
# 24                             5.853175
# 25                             0.992063
# 26                            -1.984127
# 27                            35.821542
# 28                            27.837135
# 29                            16.373087
# 30                             9.789200
# 31                             8.576379
# 32                             3.248628
# 33                            -1.645972
#
#     accumulated_percent_profit_product_of_warehouse
# 0                                         53.762136
# 1                                         67.657767
# 2                                         78.640777
# 3                                         86.893204
# 4                                         94.538835
# 5                                        100.485437
# 6                                        100.000000
# 7                                         55.984340
# 8                                         74.328859
# 9                                         89.401566
# 10                                        94.463087
# 11                                        98.042506
# 12                                       101.342282
# 13                                       100.000000
# 14                                        28.781925
# 15                                        51.113294
# 16                                        72.920760
# 17                                        92.403405
# 18                                       100.130976
# 19                                       100.000000
# 20                                        56.349206
# 21                                        73.313492
# 22                                        87.896825
# 23                                        95.138889
# 24                                       100.992063
# 25                                       101.984127
# 26                                       100.000000
# 27                                        35.821542
# 28                                        63.658677
# 29                                        80.031764
# 30                                        89.820964
# 31                                        98.397343
# 32                                       101.645972
# 33                                       100.000000

# %% [markdown]
# ## 6. Присвоить A,B,C - категории на основании значения накопленного процента ('accumulated_percent_profit_product_of_warehouse').
# Если значение накопленного процента меньше или равно 70, то категория A.
# Если от 70 до 90 (включая 90), то категория Б. Остальное - категория C. Новый столбец обозначить в таблице как 'category'

# %% [markdown]
# ### Вычисления

# %%
def set_category(row):
    if row['accumulated_percent_profit_product_of_warehouse'] <= 70:
        category = 'A'
    elif 70 < row['accumulated_percent_profit_product_of_warehouse'] <= 90:
        category = 'B'
    else:
        category = 'C'
    return category

grouped_by_warehouse_category_df = grouped_by_warehouse_df.copy()
grouped_by_warehouse_category_df['category'] = grouped_by_warehouse_category_df.apply(set_category, axis=1)

# %% [markdown]
# ### Итог

# %%
grouped_by_warehouse_category_df
# Out:
#          warehouse_name                   product  quantity  profit  \
# 0                Мордор           билет в Израиль         9    8860
# 1                Мордор  автограф Стаса Барецкого         4    2290
# 2                Мордор          статуэтка Ленина        10    1810
# 3                Мордор                   плюмбус         6    1360
# 4                Мордор     ломтик июльского неба         3    1260
# 5                Мордор    подписка на suppi-блог         8     980
# 6                Мордор         зеленая пластинка        11     -80
# 7            гиперборея           билет в Израиль        21   20020
# 8            гиперборея  автограф Стаса Барецкого        12    6560
# 9            гиперборея     ломтик июльского неба        13    5390
# 10           гиперборея                   плюмбус         9    1810
# 11           гиперборея          статуэтка Ленина         9    1280
# 12           гиперборея    подписка на suppi-блог        12    1180
# 13           гиперборея         зеленая пластинка        10    -480
# 14     остров невезения     ломтик июльского неба        10    4395
# 15     остров невезения          статуэтка Ленина        18    3410
# 16     остров невезения                   плюмбус        14    3330
# 17     остров невезения           билет в Израиль         3    2975
# 18     остров невезения  автограф Стаса Барецкого         2    1180
# 19     остров невезения         зеленая пластинка         9     -20
# 20           отель Лето           билет в Израиль        15   14200
# 21           отель Лето  автограф Стаса Барецкого         8    4275
# 22           отель Лето     ломтик июльского неба         9    3675
# 23           отель Лето                   плюмбус         9    1825
# 24           отель Лето          статуэтка Ленина        10    1475
# 25           отель Лето    подписка на suppi-блог         3     250
# 26           отель Лето         зеленая пластинка        10    -500
# 27  хутор близ Диканьки  автограф Стаса Барецкого        22   12405
# 28  хутор близ Диканьки           билет в Израиль        10    9640
# 29  хутор близ Диканьки                   плюмбус        27    5670
# 30  хутор близ Диканьки          статуэтка Ленина        21    3390
# 31  хутор близ Диканьки     ломтик июльского неба         7    2970
# 32  хутор близ Диканьки    подписка на suppi-блог        10    1125
# 33  хутор близ Диканьки         зеленая пластинка        21    -570
#
#     percent_profit_product_of_warehouse  \
# 0                             53.762136
# 1                             13.895631
# 2                             10.983010
# 3                              8.252427
# 4                              7.645631
# 5                              5.946602
# 6                             -0.485437
# 7                             55.984340
# 8                             18.344519
# 9                             15.072707
# 10                             5.061521
# 11                             3.579418
# 12                             3.299776
# 13                            -1.342282
# 14                            28.781925
# 15                            22.331369
# 16                            21.807466
# 17                            19.482646
# 18                             7.727570
# 19                            -0.130976
# 20                            56.349206
# 21                            16.964286
# 22                            14.583333
# 23                             7.242063
# 24                             5.853175
# 25                             0.992063
# 26                            -1.984127
# 27                            35.821542
# 28                            27.837135
# 29                            16.373087
# 30                             9.789200
# 31                             8.576379
# 32                             3.248628
# 33                            -1.645972
#
#     accumulated_percent_profit_product_of_warehouse category
# 0                                         53.762136        A
# 1                                         67.657767        A
# 2                                         78.640777        B
# 3                                         86.893204        B
# 4                                         94.538835        C
# 5                                        100.485437        C
# 6                                        100.000000        C
# 7                                         55.984340        A
# 8                                         74.328859        B
# 9                                         89.401566        B
# 10                                        94.463087        C
# 11                                        98.042506        C
# 12                                       101.342282        C
# 13                                       100.000000        C
# 14                                        28.781925        A
# 15                                        51.113294        A
# 16                                        72.920760        B
# 17                                        92.403405        C
# 18                                       100.130976        C
# 19                                       100.000000        C
# 20                                        56.349206        A
# 21                                        73.313492        B
# 22                                        87.896825        B
# 23                                        95.138889        C
# 24                                       100.992063        C
# 25                                       101.984127        C
# 26                                       100.000000        C
# 27                                        35.821542        A
# 28                                        63.658677        A
# 29                                        80.031764        B
# 30                                        89.820964        B
# 31                                        98.397343        C
# 32                                       101.645972        C
# 33                                       100.000000        C
